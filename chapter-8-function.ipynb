# %% [markdown]
# # 第 8 章 函数

# %% [markdown]
# ## 8.1 定义函数

# %%
def greet_user():
    """显示简单的问候语"""
    print("Hello!")
greet_user()
# Out:
# Hello!

# %% [markdown]
# ### 8.1.1 向函数传递信息

# %%
def greet_user(username):
    """显示简单的问候语"""
    print(f"Hello, {username.title()}!")

greet_user('jesse')
# Out:
# Hello, Jesse!

# %% [markdown]
# ### 8.1.2 实参与形参

# %% [markdown]
# ### 动手试一试

# %% [markdown]
# 练习 8.1：消息 编写一个名为 display_message() 的函数，让它打印一个句子，指出本章的主题是什么。调用这个函数，确认显示的消息正确无误。

# %% [markdown]
# 练习 8.2: 喜欢的书 编写一个名为 favorite_book() 的函 数，其中包含一个名为 title 的形参。让这个函数打印一条像下面这样的消息。<br>
# One of my favorite books is . <br>
# 调用这个函数，并将一本书的书名作为实参传递给它。

# %% [markdown]
# ## 8.2 传递参数

# %% [markdown]
# ### 8.2.1 位置实参

# %%
def descibe_pet(animal_type, pet_name):
    """显示宠物的信息"""
    print(f"\nI have a {animal_type}")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

descibe_pet('hamster', 'harry')
# Out:
# I have a hamster
# My hamster's name is Harry.

# %%
# 可以被多次调用
descibe_pet('dog', 'willie')
# Out:
# I have a dog
# My dog's name is Willie.

# %%
# 位置实参的顺序很重要
descibe_pet('harry', 'hamster')
# Out:
# I have a harry
# My harry's name is Hamster.

# %% [markdown]
# ### 8.2.2 关键字实参

# %%
descibe_pet(animal_type = 'hamster', pet_name = 'harry')
# Out:
# I have a hamster
# My hamster's name is Harry.

# %% [markdown]
# ### 8.2.3 默认值

# %%
def describe_pet(pet_name, animal_type='dog'):
    """显示宠物的信息"""
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(pet_name="willie")
# Out:
# I have a dog.
# My dog's name is Willie.

# %%
describe_pet("willie")
# Out:
# I have a dog.
# My dog's name is Willie.

# %%
describe_pet(pet_name="harry", animal_type="hamster")
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# ### 8.2.4 等效的函数调用

# %%
# 一条名为 Willie 的小狗
describe_pet('willie')
describe_pet(pet_name="willie")

# 一只名为 Harry 的参数
describe_pet('harry', 'hamster')
describe_pet(pet_name="harry", animal_type="hamster")
describe_pet(animal_type="hamster", pet_name="harry")
# Out:
# I have a dog.
# My dog's name is Willie.
#
# I have a dog.
# My dog's name is Willie.
#
# I have a hamster.
# My hamster's name is Harry.
#
# I have a hamster.
# My hamster's name is Harry.
#
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# ### 8.2.5 避免实参穿错

# %%
describe_pet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 describe_pet()
#
# TypeError: describe_pet() missing 1 required positional argument: 'pet_name'

# %% [markdown]
# ### 动手试一试

# %% [markdown]
# 练习 8.3：T恤 编写一个名为 make_shirt() 的函数，它接 受一个尺码以及要印到 T 恤上的字样。这个函数应该打印一个句
# 子，简要地说明 T 恤的尺码和字样。<br>
# 先使用位置实参调用这个函数来制作一件 T 恤，再使用关键字实 参来调用这个函数。

# %% [markdown]
# 练习 8.4：大号 T恤 修改 make_shirt() 函数，使其在默 认情况下制作一件印有 <br>
# “I love Python”字样的大号 T 恤。调用这个函数分别制作一 件印有默认字样的大号 T 恤，一件印有默认字样的中号 T 恤， 以及一件印有其他字样的 T 恤(尺码无关紧要)。

# %% [markdown]
# 练习 8.5：城市 编写一个名为 describe_city() 的函数， 它接受一座城市的名字以及该城市所属的国家。这个函数应该打
# 印一个像下面这样简单的句子。<br>
# Reykjavik is in Iceland. <br>
# 给用于存储国家的形参指定默认值。为三座不同的城市调用这个函数，其中至少有一座城市不属于默认的国家。

# %% [markdown]
# ## 8.3 返回值

# %% [markdown]
# ## 8.4 传递列表

# %% [markdown]
# ## 8.5 传递任意数量的实参

# %% [markdown]
# ## 8.6 将函数存储在模块中

# %% [markdown]
# ## 8.7 将函数存储在模块中
